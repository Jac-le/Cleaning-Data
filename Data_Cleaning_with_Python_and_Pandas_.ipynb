# %% [markdown]
# <a href="https://colab.research.google.com/github/Jac-le/Cleaning-Data/blob/main/Data_Cleaning_with_Python_and_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load the raw data

# %%
data = pd.read_csv('/content/drive/MyDrive/Datasets/raw_retail_sales.csv')
data
# Out:
#            Date Store     Category  Sales  Transaction_ID
# 0    2025-01-01     A  Electronics  500.0             101
# 1    2025-01-02     B    Furniture  300.0             102
# 2    2025-01-03     C          NaN    NaN             103
# 3    2025-01-04     A  Electronics -100.0             104
# 4           NaN     B     Clothing  400.0             105
# 5    2025-01-06   NaN    Furniture  600.0             106
# 6    2025-01-07     C          NaN    NaN             107
# 7    2025-01-07     C  Electronics  700.0             107
# 8    2025-01-08     A     Clothing  800.0             108
# 9  Invalid Date     A     Clothing  900.0             109

# %% [markdown]
# Inspect the data

# %%
data.head()
# Out:
#          Date Store     Category  Sales  Transaction_ID
# 0  2025-01-01     A  Electronics  500.0             101
# 1  2025-01-02     B    Furniture  300.0             102
# 2  2025-01-03     C          NaN    NaN             103
# 3  2025-01-04     A  Electronics -100.0             104
# 4         NaN     B     Clothing  400.0             105

# %%
data.describe()
# Out:
#             Sales  Transaction_ID
# count    8.000000        10.00000
# mean   512.500000       105.20000
# std    318.198052         2.65832
# min   -100.000000       101.00000
# 25%    375.000000       103.25000
# 50%    550.000000       105.50000
# 75%    725.000000       107.00000
# max    900.000000       109.00000

# %%
data.isnull().sum()
# Out:
# Date              1
# Store             1
# Category          2
# Sales             2
# Transaction_ID    0
# dtype: int64

# %%
#Handle missing values
#sales
data['Sales'] = data['Sales'].fillna(data['Sales'].mean())
data.head()
# Out:
#          Date Store     Category  Sales  Transaction_ID
# 0  2025-01-01     A  Electronics  500.0             101
# 1  2025-01-02     B    Furniture  300.0             102
# 2  2025-01-03     C          NaN  512.5             103
# 3  2025-01-04     A  Electronics -100.0             104
# 4         NaN     B     Clothing  400.0             105

# %%
data['Category'] = data['Category'].fillna('Unknown')
data.head()
# Out:
#          Date Store     Category  Sales  Transaction_ID
# 0  2025-01-01     A  Electronics  500.0             101
# 1  2025-01-02     B    Furniture  300.0             102
# 2  2025-01-03     C      Unknown  512.5             103
# 3  2025-01-04     A  Electronics -100.0             104
# 4         NaN     B     Clothing  400.0             105

# %%
data['Store'] = data['Store'].fillna('Unknown')

# %%
# Convert data types

data['Date'] = pd.to_datetime(data['Date'], errors='coerce')
data.head()
# Out:
#         Date Store     Category  Sales  Transaction_ID
# 0 2025-01-01     A  Electronics  500.0             101
# 1 2025-01-02     B    Furniture  300.0             102
# 2 2025-01-03     C      Unknown  512.5             103
# 3 2025-01-04     A  Electronics -100.0             104
# 4        NaT     B     Clothing  400.0             105

# %%
# Drop rows where 'Date' conversion failed

data = data[data['Date'].notnull()]

# %%
# Remove duplicates

data = data.drop_duplicates()
data
# Out:
#         Date    Store     Category  Sales  Transaction_ID
# 0 2025-01-01        A  Electronics  500.0             101
# 1 2025-01-02        B    Furniture  300.0             102
# 2 2025-01-03        C      Unknown  512.5             103
# 3 2025-01-04        A  Electronics -100.0             104
# 5 2025-01-06  Unknown    Furniture  600.0             106
# 6 2025-01-07        C      Unknown  512.5             107
# 7 2025-01-07        C  Electronics  700.0             107
# 8 2025-01-08        A     Clothing  800.0             108
